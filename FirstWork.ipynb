# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("../Downloads/uber.csv")
df.head(50)
# Out:
#     Unnamed: 0                            key  fare_amount  \
# 0     24238194    2015-05-07 19:52:06.0000003          7.5
# 1     27835199    2009-07-17 20:04:56.0000002          7.7
# 2     44984355   2009-08-24 21:45:00.00000061         12.9
# 3     25894730    2009-06-26 08:22:21.0000001          5.3
# 4     17610152  2014-08-28 17:47:00.000000188         16.0
# 5     44470845    2011-02-12 02:27:09.0000006          4.9
# 6     48725865    2014-10-12 07:04:00.0000002         24.5
# 7     44195482   2012-12-11 13:52:00.00000029          2.5
# 8     15822268   2012-02-17 09:32:00.00000043          9.7
# 9     50611056  2012-03-29 19:06:00.000000273         12.5
# 10     2205147    2015-05-22 17:32:27.0000004          6.5
# 11     6379048   2011-05-23 22:15:00.00000086          8.5
# 12    31892535  2011-05-17 14:03:00.000000158          3.3
# 13    13012786  2011-06-25 11:19:00.000000102         10.9
# 14    48411337    2010-04-06 22:20:27.0000004          6.9
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0    fare_amount  pickup_longitude  pickup_latitude  \
# count  2.000000e+05  200000.000000     200000.000000    200000.000000
# mean   2.771250e+07      11.359955        -72.527638        39.935885
# std    1.601382e+07       9.901776         11.437787         7.720539
# min    1.000000e+00     -52.000000      -1340.648410       -74.015515
# 25%    1.382535e+07       6.000000        -73.992065        40.734796
# 50%    2.774550e+07       8.500000        -73.981823        40.752592
# 75%    4.155530e+07      12.500000        -73.967154        40.767158
# max    5.542357e+07     499.000000         57.418457      1644.421482
#
#        dropoff_longitude  dropoff_latitude  passenger_count
# count      199999.000000     199999.000000    200000.000000
# mean          -72.525292         39.923890         1.684535
# std            13.117408          6.794829         1.385997
# min         -3356.666300       -881.985513         0.000000
# ...

# %%
df.info() #Get basic information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         200000 non-null  int64
#  1   key                200000 non-null  object
#  2   fare_amount        200000 non-null  float64
#  3   pickup_datetime    200000 non-null  object
#  4   pickup_longitude   200000 non-null  float64
#  5   pickup_latitude    200000 non-null  float64
#  6   dropoff_longitude  199999 non-null  float64
#  7   dropoff_latitude   199999 non-null  float64
#  8   passenger_count    200000 non-null  int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 13.7+ MB

# %%
df.isnull().sum() #check for sum of null values in the dataset
# Out:
# Unnamed: 0           0
# key                  0
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    1
# dropoff_latitude     1
# passenger_count      0
# dtype: int64

# %%
plt.style.use('_mpl-gallery')

# %%
x = np.linspace(0., 10., 100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
y = np.sin(np.deg2rad(x))
y
# Out:
# array([0.        , 0.00176296, 0.00352591, 0.00528885, 0.00705178,
#        0.00881468, 0.01057756, 0.0123404 , 0.0141032 , 0.01586596,
#        0.01762868, 0.01939133, 0.02115393, 0.02291646, 0.02467892,
#        0.0264413 , 0.0282036 , 0.02996581, 0.03172793, 0.03348995,
#        0.03525187, 0.03701368, 0.03877537, 0.04053694, 0.04229839,
#        0.0440597 , 0.04582088, 0.04758192, 0.0493428 , 0.05110354,
#        0.05286411, 0.05462452, 0.05638476, 0.05814483, 0.05990471,
#        0.06166441, 0.06342392, 0.06518323, 0.06694234, 0.06870124,
#        0.07045992, 0.07221839, 0.07397663, 0.07573464, 0.07749242,
#        0.07924996, 0.08100725, 0.08276428, 0.08452107, 0.08627758,
#        0.08803383, 0.08978981, 0.09154551, 0.09330092, 0.09505604,
#        0.09681087, 0.0985654 , 0.10031962, 0.10207353, 0.10382712,
#        0.10558039, 0.10733333, 0.10908593, 0.1108382 , 0.11259012,
#        0.1143417 , 0.11609291, 0.11784377, 0.11959426, 0.12134438,
# ...

# %%
plt.figure(figsize = (9, 6)) #picture container of 9 x 6 
plt.plot(x, y) #show line plot of x and y
